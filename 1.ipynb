# %%
"""
Stock Market Analysis using Time Series Relational Model
ARIMA and GARCH Time Series Forecasting

This script performs time series analysis on stock market data
using ARIMA for price forecasting and GARCH for volatility modeling.
"""

import os
import sys
import pandas as pd
import matplotlib.pyplot as plt
import warnings


# Handle path for importing local modules (works in both script and notebook)
try:
    current_dir = os.path.dirname(os.path.abspath(__file__))
except NameError:
    current_dir = os.getcwd()
sys.path.append(current_dir)

# Updated: Import the new hardcoded loader
from src.data_loader import load_data
from src.preprocessing import preprocess_data
from src.model_arima import run_arima
from src.model_garch import run_garch
from src.visualization import (
    visualize_data, 
    visualize_arima_results, 
    visualize_garch_forecast,
    visualize_comparison
)
from src.evaluation import evaluate_models

# Suppress warnings
warnings.filterwarnings("ignore")

def main():
    """Main execution function for the stock market analysis project."""
    
    print("\n" + "="*70)
    print("STOCK MARKET ANALYSIS USING TIME SERIES RELATIONAL MODEL")
    print("="*70)
    print("\nThis program performs time series analysis on stock market data using:")
    print("  - ARIMA (AutoRegressive Integrated Moving Average) for price forecasting")
    print("  - GARCH (Generalized AutoRegressive Conditional Heteroskedasticity) for volatility modeling\n")
    
    try:
        # Step 1: Load the data
        print("\nSTEP 1: LOADING DATA")
        df = load_data()  # Updated: No more user input
        
        if df is None:
            print("Error loading data. Exiting program.")
            return 1
        
        # Step 2: Preprocess the data
        print("\nSTEP 2: PREPROCESSING DATA")
        df_processed = preprocess_data(df)
        
        # Step 3: Visualize the data
        print("\nSTEP 3: VISUALIZING DATA")
        visualize_data(df_processed)
        
        # Step 4: Run ARIMA model
        print("\nSTEP 4: RUNNING ARIMA MODEL")
        forecast_periods = int(input("\nEnter the number of periods to forecast (default: 30): ") or 30)
        test_size = float(input("Enter the proportion of data to use for testing (0.0-1.0, default: 0.2): ") or 0.2)
        
        arima_results = run_arima(df_processed, forecast_periods=forecast_periods, test_size=test_size)
        visualize_arima_results(arima_results)
        
        # Step 5: Run GARCH model
        print("\nSTEP 5: RUNNING GARCH MODEL")
        garch_results = run_garch(df_processed, forecast_periods=forecast_periods, test_size=test_size)

        visualize_garch_forecast(
            train_data=garch_results.train_data,
            cond_vol=garch_results.conditional_volatility,
            forecast_dates=garch_results.forecast_dates,
            forecast_vol=garch_results.forecast_volatility,
            garch_results=garch_results
        )
        
        # Step 6: Compare models
        print("\nSTEP 6: COMPARING MODELS")
        visualize_comparison(arima_results, garch_results, df_processed)
        
        # Step 7: Evaluate models
        print("\nSTEP 7: EVALUATING MODELS")
        evaluate_models(arima_results, garch_results)
        
        print("\n" + "="*70)
        print("ANALYSIS COMPLETED SUCCESSFULLY")
        print("="*70)
        print("\nForecasts have been saved to 'forecast_results.csv'")
        
    except Exception as e:
        print("\nERROR: An error occurred during analysis.")
        print(f"Error details: {str(e)}")
        import traceback
        traceback.print_exc()
        return 1
        
    return 0

# Only run main if not in notebook
if __name__ == "__main__":
    sys.exit(main())
# Out:
# ======================================================================
# STOCK MARKET ANALYSIS USING TIME SERIES RELATIONAL MODEL
# ======================================================================
#
# This program performs time series analysis on stock market data using:
#   - ARIMA (AutoRegressive Integrated Moving Average) for price forecasting
#   - GARCH (Generalized AutoRegressive Conditional Heteroskedasticity) for volatility modeling
#
#
# STEP 1: LOADING DATA
# Loading data from: C:\Users\SUPERSTAR\OneDrive\Desktop\FE Final project\data\Cleaned_StockMarket_Data (1).csv
# Error: CSV file must contain a 'Date' column
# Generating synthetic data for analysis...
# Sample data created with 522 trading days
# Date range: 2023-04-28 09:40:55.790716 to 2025-04-28 09:40:55.790716
#
# Preview of sample data:
#                                   Open        High         Low       Close  \
# 2023-04-28 09:40:55.790716  100.400252  102.310984   98.981130  100.646057
# 2023-05-01 09:40:55.790716  100.453098  101.314089   99.744693  100.529391
# 2023-05-02 09:40:55.790716  100.688963  102.359928  100.362065  101.360996
# 2023-05-03 09:40:55.790716  104.125992  104.609099  102.254669  103.431884
# 2023-05-04 09:40:55.790716  104.158832  104.959845  102.344871  103.652358
#
#                              Volume
# 2023-04-28 09:40:55.790716   241377
# 2023-05-01 09:40:55.790716  1287716
# 2023-05-02 09:40:55.790716   614337
# 2023-05-03 09:40:55.790716  1027836
# 2023-05-04 09:40:55.790716   655883
#
# STEP 2: PREPROCESSING DATA
#
# ==================================================
# DATA PREPROCESSING
# ==================================================
# Detected 3 potential outliers in returns (|z-score| > 3)
#
# Stationarity Check for Close Price:
# ADF Statistic: -0.9005
# p-value: 0.7878
# Critical Values:
#   1%: -3.4430
#   5%: -2.8671
#   10%: -2.5697
# Result: The Close Price series is non-stationary (fail to reject H0)
# Note: Non-stationarity in price series is expected. Differencing or returns transformation recommended.
#
# Stationarity Check for Returns:
# ADF Statistic: -18.5891
# p-value: 0.0000
# Critical Values:
#   1%: -3.4430
#   5%: -2.8671
#   10%: -2.5697
# Result: The Returns series is stationary (reject H0)
#
# Preprocessed data summary:
#              Open        High         Low       Close        Volume  \
# count  492.000000  492.000000  492.000000  492.000000  4.920000e+02
# mean   114.529994  115.984503  113.086627  114.535565  1.075769e+06
# std     20.482750   20.742230   20.157675   20.443426  3.127156e+05
# min     83.856452   85.849092   83.714569   84.781830  1.271860e+05
# 25%     92.434151   93.897761   91.513788   92.700009  8.641502e+05
# 50%    113.112830  114.335546  111.507375  112.856365  1.065836e+06
# 75%    134.161096  135.983633  132.775937  134.784961  1.299526e+06
# max    159.836468  159.851684  157.827337  158.839510  1.963621e+06
#
#           Returns  Log_Returns        MA_7       MA_30  Volatility_7  \
# count  492.000000   492.000000  492.000000  492.000000    492.000000
# mean     0.080821     0.073352  114.291256  113.415071      1.134181
# std      1.222641     1.220416   20.381036   19.944660      0.356873
# min     -3.877697    -3.954882   85.957495   87.365737      0.386930
# 25%     -0.781253    -0.784321   92.360546   91.449844      0.859428
# 50%      0.096619     0.096572  112.475040  112.165192      1.114183
# 75%      0.815752     0.812443  134.624054  134.393925      1.379458
# max      4.836765     4.723434  155.762847  149.768111      2.115945
#
#        Volatility_30
# count     492.000000
# mean        1.206134
# std         0.197071
# min         0.729851
# 25%         1.066968
# 50%         1.193470
# 75%         1.358529
# max         1.645807
#
# Final dataset has 492 records after preprocessing
#
# STEP 3: VISUALIZING DATA
# Data visualizations displayed
#
# STEP 4: RUNNING ARIMA MODEL
#
# ==================================================
# ARIMA MODELING
# ==================================================
# Training data: 2023-06-09 09:40:55.790716 to 2024-10-02 09:40:55.790716 (344 records)
# Testing data: 2024-10-03 09:40:55.790716 to 2025-04-28 09:40:55.790716 (148 records)
#
# Finding optimal ARIMA parameters...
# ARIMA(0, 2, 3) - AIC: 1107.77
# ARIMA(0, 1, 0) - AIC: 1108.59
# ARIMA(2, 2, 3) - AIC: 1110.30
# ARIMA(1, 1, 0) - AIC: 1102.81
# ARIMA(3, 2, 3) - AIC: 1109.37
# ARIMA(3, 1, 3) - AIC: 1100.97
# ARIMA(0, 2, 0) - AIC: 1285.13
# ARIMA(3, 2, 1) - AIC: 1109.70
# ARIMA(0, 1, 3) - AIC: 1106.23
# ARIMA(2, 2, 1) - AIC: 1107.76
# ARIMA(2, 1, 1) - AIC: 1105.57
# ARIMA(0, 1, 2) - AIC: 1104.83
# ARIMA(2, 1, 2) - AIC: 1107.31
# ARIMA(1, 2, 1) - AIC: 1105.77
# ARIMA(0, 1, 1) - AIC: 1102.86
# ARIMA(3, 2, 2) - AIC: 1110.00
# ARIMA(2, 2, 0) - AIC: 1187.07
# ARIMA(3, 1, 0) - AIC: 1106.72
# ARIMA(1, 2, 2) - AIC: 1107.75
# ARIMA(3, 2, 0) - AIC: 1180.62
#
# Best ARIMA order: (3, 1, 3) with AIC: 1100.97
#
# Fitting ARIMA model...
#
# ARIMA Model Summary:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                  344
# Model:                 ARIMA(3, 1, 3)   Log Likelihood                -543.487
# Date:                Mon, 28 Apr 2025   AIC                           1100.974
# Time:                        09:41:10   BIC                           1127.838
# Sample:                    06-09-2023   HQIC                          1111.675
#                          - 10-02-2024
# Covariance Type:                  opg
# ==============================================================================
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6564      0.197     -3.336      0.001      -1.042      -0.271
# ar.L2         -0.8800      0.042    -20.871      0.000      -0.963      -0.797
# ar.L3         -0.6289      0.185     -3.407      0.001      -0.991      -0.267
# ma.L1          0.7676      0.174      4.410      0.000       0.426       1.109
# ma.L2          0.9759      0.064     15.352      0.000       0.851       1.100
# ma.L3          0.7885      0.172      4.574      0.000       0.451       1.126
# sigma2         1.3900      0.114     12.211      0.000       1.167       1.613
# ==============================================================================
#
# Test set metrics:
# RMSE: 10.36
# MAE: 8.32
#
# Generating 30 period forecast...
# ARIMA modeling completed.
# ARIMA visualizations displayed
#
# STEP 5: RUNNING GARCH MODEL
#
# ==================================================
# GARCH MODELING FOR VOLATILITY
# ==================================================
# Training data: 2023-06-09 09:40:55.790716 to 2024-10-02 09:40:55.790716 (344 records)
# Testing data: 2024-10-03 09:40:55.790716 to 2025-04-28 09:40:55.790716 (148 records)
#
# Finding optimal GARCH parameters...
# GARCH(1,1) - AIC: 1085.09
# GARCH(1,2) - AIC: 1087.05
# GARCH(2,1) - AIC: 1087.09
# GARCH(2,2) - AIC: 1089.05
#
# Best GARCH order: (1, 1) with AIC: 1085.09
#
# Fitting GARCH model...
#
# GARCH Model Summary:
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:            Log_Returns   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.003
# Vol Model:                      GARCH   Log-Likelihood:               -539.546
# Distribution:                  Normal   AIC:                           1085.09
# Method:            Maximum Likelihood   BIC:                           1096.61
#                                         No. Observations:                  344
# Date:                Mon, Apr 28 2025   Df Residuals:                      344
# Time:                        09:41:12   Df Model:                            0
# ==============================================================================
#
# Test set metrics for squared returns:
# RMSE: 2.388797
# MAE: 1.563427
#
# Generating 30 period forecast...
# GARCH modeling completed.
# GARCH visualizations displayed
#
# STEP 6: COMPARING MODELS
# Forecast comparison visualization displayed
#
# STEP 7: EVALUATING MODELS
#
# Evaluation of model forecasts:
# ----------------------------------------
# ARIMA RMSE: 10.3631
# ARIMA MAE: 8.3181
# ARIMA AIC: 1100.9741
# ARIMA BIC: 1127.8382
# GARCH RMSE: 2.3888
# GARCH MAE: 1.5634
# GARCH AIC: 1085.0924
# GARCH BIC: 1096.6143
#
# Forecast summary:
#                             Price_Forecast  Volatility_Forecast
# Date
# 2025-04-29 09:40:55.790716             NaN             1.184397
# 2025-04-30 09:40:55.790716             NaN             1.214070
# 2025-05-01 09:40:55.790716             NaN             1.219061
# 2025-05-02 09:40:55.790716             NaN             1.219911
# 2025-05-03 09:40:55.790716             NaN             1.220056
#
# Forecasts saved to 'forecast_results.csv'
#
# ======================================================================
# ANALYSIS COMPLETED SUCCESSFULLY
# ======================================================================
#
# Forecasts have been saved to 'forecast_results.csv'
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
